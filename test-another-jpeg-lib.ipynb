# %%
import imagecodecs

# %%
from pydicom import dcmread

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dcm = dcmread('/home/anvar/work/data/for_jpeg/1.2.40.0.13.1.1.1.192.168.200.45.20201012180832325.41805/1.2.840.113619.2.428.3.2831214542.568.1602562897.567.70.dcm')

# %%
array = dcm.pixel_array

# %%
plt.imshow(dcm.pixel_array)

# %%
array_jpeg = imagecodecs.jpeg2k_decode(imagecodecs.jpeg2k_encode(array))

# %%
import numpy as np

# %%
np.allclose(array_jpeg, array)
# Out:
# True

# %%
import inspect

# %%
imagecodecs.jpeg_encode()

# %%
inspect.signature(imagecodecs.jpeg2k_encode)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d7895884f6b7> in <module>
# ----> 1 inspect.signature(imagecodecs.jpeg2k_encode)
#
# ~/anaconda3/lib/python3.8/inspect.py in signature(obj, follow_wrapped)
#    3091 def signature(obj, *, follow_wrapped=True):
#    3092     """Get a signature object for the passed callable."""
# -> 3093     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3094
#    3095
#
# ~/anaconda3/lib/python3.8/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2840     def from_callable(cls, obj, *, follow_wrapped=True):
#    2841         """Constructs Signature for the given callable object."""
# -> 2842         return _signature_from_callable(obj, sigcls=cls,
#    2843                                         follow_wrapper_chains=follow_wrapped)
#    2844
#
# ...

# %%
imagecodecs.jpeg2k_encode()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-475f932d363d> in <module>
# ----> 1 imagecodecs.jpeg2k_encode()
#
# imagecodecs\_jpeg2k.pyx in imagecodecs._jpeg2k.jpeg2k_encode()
#
# TypeError: jpeg2k_encode() takes at least 1 positional argument (0 given)

# %%
len(imagecodecs.jpeg2k_encode(array))
# Out:
# 215695

# %%
len(dcm.PixelData)
# Out:
# 209732

# %%
len(array.tobytes())
# Out:
# 524288

# %%
np.int16()

# %%
array = np.random.randint(0, 63000, (200, 3, 128, 128)).astype(np.uint8)

# %%
array[0].shape
# Out:
# (3, 128, 128)

# %%
x = array[0].transpose(1,2,0)

# %%
dcm.pixel_array.shape
# Out:
# (512, 512)

# %%
plt.imshow(imagecodecs.jpegls_decode(imagecodecs.jpegls_encode(dcm.pixel_array.astype(np.uint8))), cmap='gray')

# %%
dcm
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.428.3.2831214542.568.1602562897.567.70
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.9.3811.1.5.3
# (0002, 0013) Implementation Version Name         SH: 'PYNETDICOM_153'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '20201013'
# (0008, 0013) Instance Creation Time              TM: '185041'
# ...

# %%
plt.imshow(imagecodecs.jpeg2k_decode(imagecodecs.jpeg2k_encode(array)))
